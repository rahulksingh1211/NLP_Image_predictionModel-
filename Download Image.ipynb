# %%
#Importing common Lib
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

#importing selenium web driver
from selenium import webdriver

#for press the enter
from selenium.webdriver.common.keys import Keys

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

#for saving the image file
import urllib.request

#for the right click button
from selenium.webdriver import ActionChains

# %%
#importing the driver for Chrome
driver=webdriver.Chrome(r'D:\Datatrained\Web Scrapping\chromedriver.exe')

#send get request to the webpage server to get the source code of the page
url=('https://www.amazon.in/')
driver.get(url)

time.sleep(3)
#twotabsearchtextbox
amazon_sear=driver.find_element_by_id('twotabsearchtextbox')
amazon_sear.send_keys('Sarees')

#Click on search
amazon_sear=driver.find_element_by_id('nav-search-submit-button')
amazon_sear.click()

time.sleep(3)
#fetching the product url
prd_url=[]
for q in driver.find_elements_by_xpath('//ul[@class="a-pagination"]/li/a'):
    prd_url.append(q.get_attribute('href'))


img_urls = []
img_data = []
for i in prd_url[:3]:
    driver.get(i)
    
    images = driver.find_elements_by_xpath('//img[@class="s-image"]')
    for image in images:
        source= image.get_attribute('src')
        if source is not None:
            if(source[0:4] == 'http'):
                img_urls.append(source)
    
for i in range(len(img_urls)):
    if i >= 160:
        break
    print("Downloading {0} of {1} images" .format(i, 160))
    response= requests.get(img_urls[i])
    file = open(r"D:\Amz Product\Saree"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
amazon_sear=driver.find_element_by_id('twotabsearchtextbox')
amazon_sear.clear()
amazon_sear.send_keys('Trousers  for men')

#Click on search
amazon_sear=driver.find_element_by_id('nav-search-submit-button')
amazon_sear.click()

time.sleep(3)
#fetching the product url
prd_url=[]
for q in driver.find_elements_by_xpath('//ul[@class="a-pagination"]/li/a'):
    prd_url.append(q.get_attribute('href'))


img_urls = []
img_data = []
for i in prd_url[:3]:
    driver.get(i)
    
    images = driver.find_elements_by_xpath('//img[@class="s-image"]')
    for image in images:
        source= image.get_attribute('src')
        if source is not None:
            if(source[0:4] == 'http'):
                img_urls.append(source)
    
for i in range(len(img_urls)):
    if i >= 160:
        break
    print("Downloading {0} of {1} images" .format(i, 160))
    response= requests.get(img_urls[i])
    file = open(r"D:\Amz Product\Trousers"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
amazon_sear=driver.find_element_by_id('twotabsearchtextbox')
amazon_sear.clear()
amazon_sear.send_keys('Jeans for men')

#Click on search
amazon_sear=driver.find_element_by_id('nav-search-submit-button')
amazon_sear.click()

time.sleep(3)
#fetching the product url
prd_url=[]
for q in driver.find_elements_by_xpath('//ul[@class="a-pagination"]/li/a'):
    prd_url.append(q.get_attribute('href'))


img_urls = []
img_data = []
for i in prd_url[:3]:
    driver.get(i)
    
    images = driver.find_elements_by_xpath('//img[@class="s-image"]')
    for image in images:
        source= image.get_attribute('src')
        if source is not None:
            if(source[0:4] == 'http'):
                img_urls.append(source)
    
for i in range(len(img_urls)):
    if i >= 160:
        break
    print("Downloading {0} of {1} images" .format(i, 160))
    response= requests.get(img_urls[i])
    file = open(r"D:\Amz Product\Jeans"+str(i)+".jpg", "wb")
    file.write(response.content)
